# %%
import gradio as gr

# %%
#pip install ipywidgets

# %%
from fastai.vision.all import *

# %%
model=load_learner('image_classifier.pkl')
# Out:
# C:\Users\sanjay\anaconda3\envs\whisper\lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %%
categories=('Cat','Dog')
def classify(img):
    pred,_,prob=model.predict(img)
    return dict(zip(categories,map(float,prob)))

# %%
img=gr.Image(height=192,width=192)
lable=gr.Label()
intf=gr.Interface(fn=classify,inputs=img,outputs=lable)
intf.launch(inline=False)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
